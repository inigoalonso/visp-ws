# %%
import pandas as pd
import numpy as np

# %%
# ignore first line of csv file and first column
df_s1_risk = pd.read_csv(
    "risk/s1_risk.csv",
    index_col=False,
    header=None,
)

# %%
df_s1_risk
# Out:
#           0         1         2         3         4         5         6   \
# 0        NaN  0.292086  0.285236  0.087940  0.075167  0.057955  0.011221
# 1   0.170134       NaN  0.683683  0.150302  0.150195  0.106108  0.016719
# 2   0.005500  0.061457       NaN  0.027338  0.018273  0.013124  0.001686
# 3   0.003708  0.013687  0.027738       NaN  0.016970  0.021409  0.001534
# 4   0.019096  0.064694  0.091635  0.081104       NaN  0.121518  0.011166
# 5   0.002102  0.009368  0.013246  0.021373  0.025509       NaN  0.002173
# 6   0.021634  0.010701  0.011521  0.009375  0.013958  0.012935       NaN
# 7   0.006889  0.005891  0.006029  0.004694  0.005440  0.005599  0.005419
# 8   0.008036  0.007168  0.007338  0.005723  0.006659  0.006825  0.006636
# 9   0.027246  0.042360  0.042880  0.021702  0.032270  0.022803  0.010688
# 10  0.020170  0.020266  0.022017  0.013401  0.021402  0.016066  0.017477
# 11  0.034667  0.036606  0.038735  0.026143  0.046308  0.034000  0.040899
# ...

# %%
files_to_read = [
    "s1_electro_impact.csv",
    "s2_electro_impact.csv",
    "s3_electro_impact.csv",
    "s1_electro_likelihood.csv",
    "s2_electro_likelihood.csv",
    "s3_electro_likelihood.csv",
    "s1_force_impact.csv",
    "s2_force_impact.csv",
    "s3_force_impact.csv",
    "s1_force_likelihood.csv",
    "s2_force_likelihood.csv",
    "s3_force_likelihood.csv",
    "s1_thermo_impact.csv",
    "s2_thermo_impact.csv",
    "s3_thermo_impact.csv",
    "s1_thermo_likelihood.csv",
    "s2_thermo_likelihood.csv",
    "s3_thermo_likelihood.csv",
]

# %%
for file in files_to_read:
    # df = pd.read_csv(file,index_col=False)
    # print(file)
    # print(df.head())
    arr = np.loadtxt("s1_electro_impact.csv",
        delimiter=",", dtype=str)
    display(arr)
    print("######################################################################")
# Out:
# array([['"CLUSTER LEVEL 0"', '"ELEMENT NAME"', '"HIERARCHY ID"',
#         '"1.01"', '"1.02"', '"1.03"', '"1.04"', '"1.05"', '"1.06"',
#         '"1.07"', '"1.08"', '"1.09"', '"1.10"', '"1.11"', '"1.12"',
#         '"1.13"', '"1.14"', '"1.15"', ''],
#        ['"SYSTEM"', '"Wheel front axle"', '"1.01"', '" "',
#         '"0.20150684700008967"', '"0.2022620557260767"',
#         '"0.20501382193699144"', '"0.44348169165840595"',
#         '"0.21143043239164375"', '"0.20815855397545507"',
#         '"0.5074744706292877"', '"0.46341582449880275"',
#         '"0.2031875227795841"', '"0.20572582100318762"',
#         '"0.2064258483991077"', '"0.20502129147035586"',
#         '"0.20334889119388605"', '"0.20415707268771782"', ''],
#        ['"SYSTEM"', '"Hub front axle"', '"1.02"',
#         '"0.20021710696452852"', '" "', '"0.20027286720953263"',
#         '"0.20070708664941694"', '"0.2005866593735022"',
#         '"0.20053110771421515"', '"0.20015249578141472"',
# ...
